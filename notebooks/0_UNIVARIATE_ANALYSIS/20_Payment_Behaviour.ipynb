# %% [markdown]
# # <font color = 'red'> Dependencias

# %%
import pandas as pd

import sys
import os

# Agregar la carpeta calibration_code al path
sys.path.append(os.path.abspath("../../calibration_code"))

# Ahora puedes importar los módulos personalizados
from modelling_tools import plot_histogram, plot_univariate_freq
from utils import g
from config import get_data_path, get_code_path
from data_cleaning import check_dataframe_quality

# %% [markdown]
# # <font color = 'red'> Carga de Datos

# %%
df = pd.read_csv(get_data_path("Credit_score_cleaned_data.csv"))

# %% [markdown]
# # <font color = 'red'> Análisis

# %%
# Todas las categorías sobre el comportamiento del cliente tienen pesos superiores al 5%:
# La categoría más riesgosa debería ser la de alto gasto con pagos pequeños, la cual pesa un 20.81%, esto se
# podría corroborar en el análisis bivariado.

plot_univariate_freq(df, 'Payment_Behaviour', figsize=(900, 600), normalize=True)

# %%
# Para tener en cuenta en el análisis bivariado (nivel de riesgo):

# %% [markdown]
# ![image.png](attachment:image.png)
